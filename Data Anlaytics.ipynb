# %%
import pandas as pd

# %%
dataframe = pd.read_csv('HR_Analytics_Dataset.csv')

# %%
dataframe.head()
# Out:
#   EmployeeID              Name  Age  Gender Location Department  \
# 0    EMP0001  Caitlin Calderon   35    Male   Sydney    Finance
# 1    EMP0002      Eric Chapman   37   Other   London         HR
# 2    EMP0003    Daniel Gregory   55  Female   Mumbai    Finance
# 3    EMP0004   Jennifer Cortez   52    Male   Sydney  Marketing
# 4    EMP0005     Daniel Butler   57   Other   Berlin         HR
#
#                JobRole DegreeEducation    HireDate Experience EmploymentType  \
# 0    Software Engineer         Diploma  04-02-2022    2.4 yrs      Part-time
# 1      Product Manager       Bachelors  20-01-2021    3.4 yrs      Part-time
# 2           HR Manager       Bachelors  15-03-2020    5.3 yrs      Part-time
# 3   Operations Manager         Diploma  22-06-2018    6.2 yrs      Full-time
# 4  Marketing Executive             PhD  10-12-2021    4.5 yrs      Full-time
#
#           Salary  PerformanceRating Attrition MaritalStatus WorkMode  \
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmployeeID             500 non-null    object
#  1   Name                   500 non-null    object
#  2   Age                    500 non-null    int64
#  3   Gender                 500 non-null    object
#  4   Location               500 non-null    object
#  5   Department             500 non-null    object
#  6   JobRole                500 non-null    object
#  7   DegreeEducation        500 non-null    object
#  8   HireDate               500 non-null    object
#  9   Experience             500 non-null    object
#  10  EmploymentType         500 non-null    object
#  11  Salary                 500 non-null    object
#  12  PerformanceRating      500 non-null    int64
#  13  Attrition              500 non-null    object
# ...

# %%
dataframe.describe(include='all')
# Out:
#        EmployeeID           Name         Age Gender Location Department  \
# count         500            500  500.000000    500      500        500
# unique        500            498         NaN      3        8          6
# top       EMP0500  Michael Miles         NaN   Male   Mumbai  Marketing
# freq            1              2         NaN    175       77         93
# mean          NaN            NaN   40.474000    NaN      NaN        NaN
# std           NaN            NaN   10.955792    NaN      NaN        NaN
# min           NaN            NaN   22.000000    NaN      NaN        NaN
# 25%           NaN            NaN   31.000000    NaN      NaN        NaN
# 50%           NaN            NaN   40.000000    NaN      NaN        NaN
# 75%           NaN            NaN   50.000000    NaN      NaN        NaN
# max           NaN            NaN   60.000000    NaN      NaN        NaN
#
#                    JobRole DegreeEducation    HireDate Experience  \
# ...

# %%
dataframe.describe()
# Out:
#               Age  PerformanceRating  TrainingHours  OvertimeHoursPerMonth  \
# count  500.000000         500.000000     500.000000             500.000000
# mean    40.474000           3.008000      54.082000              15.034000
# std     10.955792           1.408511      26.252117               8.678911
# min     22.000000           1.000000      10.000000               0.000000
# 25%     31.000000           2.000000      33.000000               8.000000
# 50%     40.000000           3.000000      52.000000              15.000000
# 75%     50.000000           4.000000      77.000000              22.000000
# max     60.000000           5.000000     100.000000              30.000000
#
#        ProjectsHandled  SatisfactionScore
# count       500.000000         500.000000
# mean          5.196000           5.374000
# std           2.894536           2.902235
# min           1.000000           1.000000
# 25%           3.000000           3.000000
# ...

# %%
dataframe.isnull().sum()
# Out:
# EmployeeID               0
# Name                     0
# Age                      0
# Gender                   0
# Location                 0
# Department               0
# JobRole                  0
# DegreeEducation          0
# HireDate                 0
# Experience               0
# EmploymentType           0
# Salary                   0
# PerformanceRating        0
# Attrition                0
# MaritalStatus            0
# WorkMode                 0
# TrainingHours            0
# OvertimeHoursPerMonth    0
# ProjectsHandled          0
# SatisfactionScore        0
# dtype: int64

# %%
dataframe.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Location', 'Department',
#        'JobRole', 'DegreeEducation', 'HireDate', 'Experience',
#        'EmploymentType', 'Salary', 'PerformanceRating', 'Attrition',
#        'MaritalStatus', 'WorkMode', 'TrainingHours', 'OvertimeHoursPerMonth',
#        'ProjectsHandled', 'SatisfactionScore'],
#       dtype='object')

# %%
dataframe = dataframe.rename(columns={'DegreeEducation':'Degree_Education'})

# %%
dataframe.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Gender', 'Location', 'Department',
#        'JobRole', 'Degree_Education', 'HireDate', 'Experience',
#        'EmploymentType', 'Salary', 'PerformanceRating', 'Attrition',
#        'MaritalStatus', 'WorkMode', 'TrainingHours', 'OvertimeHoursPerMonth',
#        'ProjectsHandled', 'SatisfactionScore'],
#       dtype='object')

# %%
# Age_group
labels = ['Adult','Middle-Aged','Senior']
dataframe['Age_group'] = pd.qcut(dataframe['Age'], q=3, labels = labels)

# %%
dataframe[['Age','Age_group']].head(10)
# Out:
#    Age    Age_group
# 0   35  Middle-Aged
# 1   37  Middle-Aged
# 2   55       Senior
# 3   52       Senior
# 4   57       Senior
# 5   55       Senior
# 6   37  Middle-Aged
# 7   40  Middle-Aged
# 8   52       Senior
# 9   25        Adult

# %%
age_data = dataframe['Age']
print(age_data)
# Out:
# 0      35
# 1      37
# 2      55
# 3      52
# 4      57
#        ..
# 495    42
# 496    56
# 497    55
# 498    46
# 499    44
# Name: Age, Length: 500, dtype: int64

# %%
dataframe['Age'].value_counts()
# Out:
# Age
# 35    19
# 27    18
# 32    17
# 46    17
# 44    17
# 37    16
# 26    16
# 34    16
# 52    15
# 30    15
# 24    15
# 38    14
# 56    14
# 53    14
# 55    14
# 41    14
# 43    14
# 57    13
# 40    13
# 42    13
# 48    12
# 39    12
# 47    12
# 31    12
# 25    11
# 50    11
# 29    11
# 58    11
# 54    10
# 23    10
# 49    10
# 33    10
# 28    10
# 59    10
# 36    10
# 22    10
# 60     9
# 45     8
# 51     7
# Name: count, dtype: int64

# %%
df['Age_group'].value_counts()
# Out:
# Age_group
# Adult          171
# Middle-Aged    167
# Senior         162
# Name: count, dtype: int64

# %%
gender = dataframe['Gender']
print(gender)
# Out:
# 0        Male
# 1       Other
# 2      Female
# 3        Male
# 4       Other
#         ...
# 495      Male
# 496     Other
# 497    Female
# 498    Female
# 499    Female
# Name: Gender, Length: 500, dtype: object

# %%
dataframe['Gender'].value_counts()
# Out:
# Gender
# Male      175
# Other     164
# Female    161
# Name: count, dtype: int64

# %%
dataframe['Location'].value_counts()
# Out:
# Location
# Mumbai       77
# New York     73
# Sydney       64
# Toronto      60
# Tokyo        59
# London       59
# Singapore    57
# Berlin       51
# Name: count, dtype: int64

# %%
dataframe['Department'].value_counts()
# Out:
# Department
# Marketing     93
# Operations    90
# Finance       89
# HR            87
# IT            77
# Sales         64
# Name: count, dtype: int64

# %%
dataframe['Degree_Education'].value_counts()
# Out:
# Degree_Education
# Masters      144
# PhD          126
# Diploma      118
# Bachelors    112
# Name: count, dtype: int64

# %%
dataframe['JobRole'].value_counts()
# Out:
# JobRole
# Operations Manager     63
# HR Manager             59
# Sales Associate        53
# IT Support             53
# Finance Analyst        51
# Business Consultant    48
# Marketing Executive    45
# Software Engineer      45
# Product Manager        42
# Data Analyst           41
# Name: count, dtype: int64

# %%
dataframe['EmploymentType'].value_counts()
# Out:
# EmploymentType
# Part-time    183
# Full-time    170
# Contract     147
# Name: count, dtype: int64

# %%
dataframe['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Single      174
# Divorced    170
# Married     156
# Name: count, dtype: int64

# %%
dataframe['WorkMode'].value_counts()
# Out:
# WorkMode
# On-site    184
# Hybrid     171
# Remote     145
# Name: count, dtype: int64

# %%
dataframe[['Employee_Name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 dataframe[['Employee_Name']]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
dataframe[dataframe['Age'] < 30]
# Out:
#     EmployeeID               Name  Age  Gender   Location  Department  \
# 9      EMP0010        Eric Cooper   25    Male     Sydney       Sales
# 19     EMP0020  Miss Hannah Kelly   23    Male   New York   Marketing
# 26     EMP0027   Michelle Russell   25    Male     London          HR
# 29     EMP0030         Gina Klein   24    Male     Berlin          HR
# 32     EMP0033      Katie Carlson   24    Male   New York          HR
# ..         ...                ...  ...     ...        ...         ...
# 474    EMP0475         Alan Perez   25    Male    Toronto       Sales
# 478    EMP0479     Phillip Walker   29  Female     Mumbai   Marketing
# 481    EMP0482    Shannon Sanchez   24    Male  Singapore       Sales
# 485    EMP0486      Thomas Norris   27    Male     Mumbai          HR
# 490    EMP0491    Austin Ferguson   26   Other     London  Operations
#
#                  JobRole Degree_Education    HireDate Experience  ...  \
# ...

# %%
dataframe[dataframe['Age'] == 30]
# Out:
#     EmployeeID                  Name  Age  Gender   Location  Department  \
# 27     EMP0028         Amanda Cooley   30    Male     Mumbai          IT
# 88     EMP0089  Mr. Stanley Griffith   30   Other    Toronto          HR
# 90     EMP0091       Alexander Noble   30   Other  Singapore   Marketing
# 91     EMP0092       Justin Cummings   30    Male     London   Marketing
# 150    EMP0151         Jasmine Woods   30  Female     Mumbai     Finance
# 260    EMP0261          Gary Stevens   30   Other     Mumbai          IT
# 286    EMP0287         Janet Jimenez   30    Male   New York       Sales
# 289    EMP0290          Julie Nelson   30    Male   New York          IT
# 333    EMP0334         Danny Wiggins   30    Male      Tokyo          IT
# 365    EMP0366            Jacob Lamb   30   Other      Tokyo  Operations
# 385    EMP0386       Hannah Thompson   30    Male  Singapore     Finance
# 410    EMP0411         Andrew Fisher   30    Male    Toronto          HR
# ...

# %%
dataframe[dataframe['Gender'] == 'Male']
# Out:
#     Employee_ID        Employee_Name  Age Gender  Location Department  \
# 0       EMP0001     Caitlin Calderon   35   Male    Sydney    Finance
# 3       EMP0004      Jennifer Cortez   52   Male    Sydney  Marketing
# 9       EMP0010          Eric Cooper   25   Male    Sydney      Sales
# 12      EMP0013         Scott Cooper   57   Male     Tokyo    Finance
# 13      EMP0014           Kim Grimes   47   Male   Toronto    Finance
# ..          ...                  ...  ...    ...       ...        ...
# 486     EMP0487           Beth Flynn   40   Male    Sydney  Marketing
# 487     EMP0488       Richard Howard   33   Male    Sydney  Marketing
# 489     EMP0490       Joshua Gregory   47   Male  New York         IT
# 493     EMP0494        David Chapman   31   Male    London    Finance
# 495     EMP0496  Ms. Alicia Mills MD   42   Male    Berlin      Sales
#
#                  JobRole Degree_Education    HireDate Experience  ...  \
# ...

# %%
dataframe[dataframe['Location'] == 'Mumbai']
# Out:
#     EmployeeID              Name  Age  Gender Location  Department  \
# 2      EMP0003    Daniel Gregory   55  Female   Mumbai     Finance
# 18     EMP0019       Janet Welch   51  Female   Mumbai       Sales
# 23     EMP0024       Regina Pope   40  Female   Mumbai          IT
# 27     EMP0028     Amanda Cooley   30    Male   Mumbai          IT
# 41     EMP0042  Kimberly Johnson   58  Female   Mumbai  Operations
# ..         ...               ...  ...     ...      ...         ...
# 470    EMP0471    Nicholas Baker   54   Other   Mumbai     Finance
# 472    EMP0473   Michael Rowland   32  Female   Mumbai       Sales
# 473    EMP0474       Ann Swanson   23   Other   Mumbai  Operations
# 478    EMP0479    Phillip Walker   29  Female   Mumbai   Marketing
# 485    EMP0486     Thomas Norris   27    Male   Mumbai          HR
#
#                  JobRole Degree_Education    HireDate Experience  ...  \
# 2             HR Manager        Bachelors  15-03-2020    5.3 yrs  ...
# ...

# %%
dataframe[(dataframe['Age'] >= 20) & (dataframe['Age'] <= 40)]
# Out:
#     EmployeeID              Name  Age  Gender  Location  Department  \
# 0      EMP0001  Caitlin Calderon   35    Male    Sydney     Finance
# 1      EMP0002      Eric Chapman   37   Other    London          HR
# 6      EMP0007       Robert Webb   37  Female  New York   Marketing
# 7      EMP0008      Sheila Ramos   40  Female    Sydney       Sales
# 9      EMP0010       Eric Cooper   25    Male    Sydney       Sales
# ..         ...               ...  ...     ...       ...         ...
# 485    EMP0486     Thomas Norris   27    Male    Mumbai          HR
# 486    EMP0487        Beth Flynn   40    Male    Sydney   Marketing
# 487    EMP0488    Richard Howard   33    Male    Sydney   Marketing
# 490    EMP0491   Austin Ferguson   26   Other    London  Operations
# 493    EMP0494     David Chapman   31    Male    London     Finance
#
#                  JobRole Degree_Education    HireDate Experience  ...  \
# 0      Software Engineer          Diploma  04-02-2022    2.4 yrs  ...
# ...

# %%
dataframe[dataframe['Degree_Education'] == 'PhD']
# Out:
#     EmployeeID             Name  Age  Gender   Location  Department  \
# 4      EMP0005    Daniel Butler   57   Other     Berlin          HR
# 5      EMP0006     Adam Shannon   55   Other    Toronto  Operations
# 8      EMP0009     Kara Delgado   52  Female    Toronto     Finance
# 9      EMP0010      Eric Cooper   25    Male     Sydney       Sales
# 25     EMP0026    Monica Harper   39  Female  Singapore          IT
# ..         ...              ...  ...     ...        ...         ...
# 485    EMP0486    Thomas Norris   27    Male     Mumbai          HR
# 486    EMP0487       Beth Flynn   40    Male     Sydney   Marketing
# 489    EMP0490   Joshua Gregory   47    Male   New York          IT
# 497    EMP0498     Linda Carter   55  Female     London       Sales
# 498    EMP0499  Patrick Johnson   46  Female     Berlin   Marketing
#
#                  JobRole Degree_Education    HireDate Experience  ...  \
# 4    Marketing Executive              PhD  10-12-2021    4.5 yrs  ...
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('HR_Analytics_Dataset.csv')

# %%
df.head()
# Out:
#   EmployeeID              Name  Age  Gender Location Department  \
# 0    EMP0001  Caitlin Calderon   35    Male   Sydney    Finance
# 1    EMP0002      Eric Chapman   37   Other   London         HR
# 2    EMP0003    Daniel Gregory   55  Female   Mumbai    Finance
# 3    EMP0004   Jennifer Cortez   52    Male   Sydney  Marketing
# 4    EMP0005     Daniel Butler   57   Other   Berlin         HR
#
#                JobRole DegreeEducation    HireDate Experience EmploymentType  \
# 0    Software Engineer         Diploma  04-02-2022    2.4 yrs      Part-time
# 1      Product Manager       Bachelors  20-01-2021    3.4 yrs      Part-time
# 2           HR Manager       Bachelors  15-03-2020    5.3 yrs      Part-time
# 3   Operations Manager         Diploma  22-06-2018    6.2 yrs      Full-time
# 4  Marketing Executive             PhD  10-12-2021    4.5 yrs      Full-time
#
#           Salary  PerformanceRating Attrition MaritalStatus WorkMode  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   EmployeeID             500 non-null    object
#  1   Name                   500 non-null    object
#  2   Age                    500 non-null    int64
#  3   Gender                 500 non-null    object
#  4   Location               500 non-null    object
#  5   Department             500 non-null    object
#  6   JobRole                500 non-null    object
#  7   DegreeEducation        500 non-null    object
#  8   HireDate               500 non-null    object
#  9   Experience             500 non-null    object
#  10  EmploymentType         500 non-null    object
#  11  Salary                 500 non-null    object
#  12  PerformanceRating      500 non-null    int64
#  13  Attrition              500 non-null    object
# ...

# %%
df[df['Experience'] == 'Fresher']
# Out:
#     EmployeeID                    Name  Age  Gender   Location  Department  \
# 11     EMP0012        Jennifer Wheeler   32   Other     Sydney     Finance
# 15     EMP0016              Bryan Hill   47  Female     Berlin   Marketing
# 23     EMP0024             Regina Pope   40  Female     Mumbai          IT
# 30     EMP0031             Aaron Brock   35   Other     Sydney  Operations
# 47     EMP0048          Tina Henderson   38   Other   New York          IT
# 48     EMP0049          Brandon Castro   50  Female     Mumbai          IT
# 57     EMP0058          Annette Bailey   52   Other     Mumbai          HR
# 59     EMP0060       Benjamin Williams   46  Female    Toronto     Finance
# 66     EMP0067            Brandi Green   24   Other   New York          HR
# 71     EMP0072        Mr. James Rivera   34  Female     Mumbai   Marketing
# 77     EMP0078             Scott Jones   49   Other      Tokyo          HR
# ...

# %%
fresher_df = df[df['Experience'] == 'Fresher']
print(fresher_df)
# Out:
#     EmployeeID                    Name  Age  Gender   Location  Department  \
# 11     EMP0012        Jennifer Wheeler   32   Other     Sydney     Finance
# 15     EMP0016              Bryan Hill   47  Female     Berlin   Marketing
# 23     EMP0024             Regina Pope   40  Female     Mumbai          IT
# 30     EMP0031             Aaron Brock   35   Other     Sydney  Operations
# 47     EMP0048          Tina Henderson   38   Other   New York          IT
# 48     EMP0049          Brandon Castro   50  Female     Mumbai          IT
# 57     EMP0058          Annette Bailey   52   Other     Mumbai          HR
# 59     EMP0060       Benjamin Williams   46  Female    Toronto     Finance
# 66     EMP0067            Brandi Green   24   Other   New York          HR
# 71     EMP0072        Mr. James Rivera   34  Female     Mumbai   Marketing
# 77     EMP0078             Scott Jones   49   Other      Tokyo          HR
# ...

# %%
df[df['EmploymentType'] == 'Part-time']
# Out:
#     EmployeeID                 Name  Age  Gender   Location Department  \
# 0      EMP0001     Caitlin Calderon   35    Male     Sydney    Finance
# 1      EMP0002         Eric Chapman   37   Other     London         HR
# 2      EMP0003       Daniel Gregory   55  Female     Mumbai    Finance
# 6      EMP0007          Robert Webb   37  Female   New York  Marketing
# 7      EMP0008         Sheila Ramos   40  Female     Sydney      Sales
# ..         ...                  ...  ...     ...        ...        ...
# 477    EMP0478         Nancy Sutton   60    Male     Sydney         IT
# 482    EMP0483            Dawn Cole   50   Other  Singapore      Sales
# 491    EMP0492           Olivia Liu   53   Other     London      Sales
# 493    EMP0494        David Chapman   31    Male     London    Finance
# 495    EMP0496  Ms. Alicia Mills MD   42    Male     Berlin      Sales
#
#                  JobRole DegreeEducation    HireDate Experience  \
# ...

# %%
df['EmploymentType'].value_counts()['Part-time']
# Out:
# np.int64(183)

# %%
df['Experience'].value_counts()['Fresher']
# Out:
# np.int64(53)

# %%
df['Experience'].value_counts()
# Out:
# Experience
# Fresher     53
# 8.9 yrs     11
# 5.1 yrs     11
# 1.5 yrs     10
# 8.2 yrs     10
#             ..
# 3.0 yrs      1
# 10.4 yrs     1
# 10.6 yrs     1
# 5.2 yrs      1
# 7.8 yrs      1
# Name: count, Length: 94, dtype: int64
